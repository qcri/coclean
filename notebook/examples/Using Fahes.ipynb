# %%
import warnings
import sys

warnings.filterwarnings('ignore')
sys.path.append('../')
sys.path.append('../fahes_service')

# %%
import pandas as pd

df = pd.read_csv('pima-indians-diabetes.csv')
df
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# 5                           5                           116
# 6                           3                            78
# 7                          10                           115
# 8                           2                           197
# 9                           8                           125
# 10                          4                           110
# 11                         10                           168
# 12                         10                           139
# 13                          1                           189
# 14                          5                           166
# ...

# %%
from fahes_api import callFahes_w_df as fahes

metadata = fahes(df, 'results')

# %%
metadata
# Out:
# {'Fahes': {'Cell_errors': [(6, 0),
#    (20, 0),
#    (31, 0),
#    (32, 0),
#    (40, 0),
#    (80, 0),
#    (108, 0),
#    (110, 0),
#    (126, 0),
#    (132, 0),
#    (140, 0),
#    (166, 0),
#    (169, 0),
#    (190, 0),
#    (197, 0),
#    (227, 0),
#    (234, 0),
#    (242, 0),
#    (256, 0),
#    (260, 0),
#    (261, 0),
#    (263, 0),
#    (272, 0),
#    (304, 0),
#    (313, 0),
#    (316, 0),
#    (317, 0),
#    (318, 0),
#    (321, 0),
#    (347, 0),
#    (348, 0),
#    (352, 0),
#    (354, 0),
#    (368, 0),
#    (370, 0),
#    (389, 0),
#    (396, 0),
#    (398, 0),
#    (399, 0),
#    (415, 0),
#    (419, 0),
#    (431, 0),
#    (480, 0),
#    (494, 0),
#    (501, 0),
#    (504, 0),
#    (514, 0),
#    (515, 0),
#    (521, 0),
#    (524, 0),
#    (525, 0),
#    (527, 0),
#    (539, 0),
#    (541, 0),
#    (551, 0),
#    (570, 0),
#    (572, 0),
#    (588, 0),
#    (592, 0),
#    (610, 0),
#    (611, 0),
#    (615, 0),
#    (644, 0),
#    (659, 0),
#    (673, 0),
# ...

# %%
import collaborative_data_frame as cdf

df = cdf.CollaborativeDataFrame(df, metadata = metadata)

df

# %%
df.share()
# Out:
# 'http://127.0.0.1/dataset/5d46e6251a9e10aeccde1ae7'
