# %%
import warnings
import sys

warnings.filterwarnings('ignore')
sys.path.append('../')

# %%
import pandas as pd

df = pd.read_csv('~/Downloads/pima-indians-diabetes.csv')
df
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# 5                           5                           116
# 6                           3                            78
# 7                          10                           115
# 8                           2                           197
# 9                           8                           125
# 10                          4                           110
# 11                         10                           168
# 12                         10                           139
# 13                          1                           189
# 14                          5                           166
# 15                          7                           100
# 16                          0                           118
# 17                          7                           107
# 18                          1                           103
# 19                          1                           115
# 20                          3                           126
# 21                          8                            99
# 22                          7                           196
# 23                          9                           119
# 24                         11                           143
# 25                         10                           125
# 26                          7                           147
# 27                          1                            97
# 28                         13                           145
# 29                          5                           117
# ..                        ...                           ...
# 738                         2                            99
# 739                         1                           102
# 740                        11                           120
# 741                         3                           102
# 742                         1                           109
# 743                         9                           140
# 744                        13                           153
# 745                        12                           100
# 746                         1                           147
# 747                         1                            81
# 748                         3                           187
# 749                         6                           162
# 750                         4                           136
# 751                         1                           121
# 752                         3                           108
# 753                         0                           181
# 754                         8                           154
# 755                         1                           128
# 756                         7                           137
# 757                         0                           123
# 758                         1                           106
# 759                         6                           190
# 760                         2                            88
# 761                         9                           170
# 762                         9                            89
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure  Triceps skin fold thickness  \
# 0                          72                           35
# 1                          66                           29
# 2                          64                            0
# 3                          66                           23
# 4                          40                           35
# 5                          74                            0
# 6                          50                           32
# 7                           0                            0
# 8                          70                           45
# 9                          96                            0
# 10                         92                            0
# 11                         74                            0
# 12                         80                            0
# 13                         60                           23
# 14                         72                           19
# 15                          0                            0
# 16                         84                           47
# 17                         74                            0
# 18                         30                           38
# 19                         70                           30
# 20                         88                           41
# 21                         84                            0
# 22                         90                            0
# 23                         80                           35
# 24                         94                           33
# 25                         70                           26
# 26                         76                            0
# 27                         66                           15
# 28                         82                           19
# 29                         92                            0
# ..                        ...                          ...
# 738                        60                           17
# 739                        74                            0
# 740                        80                           37
# 741                        44                           20
# 742                        58                           18
# 743                        94                            0
# 744                        88                           37
# 745                        84                           33
# 746                        94                           41
# 747                        74                           41
# 748                        70                           22
# 749                        62                            0
# 750                        70                            0
# 751                        78                           39
# 752                        62                           24
# 753                        88                           44
# 754                        78                           32
# 755                        88                           39
# 756                        90                           41
# 757                        72                            0
# 758                        76                            0
# 759                        92                            0
# 760                        58                           26
# 761                        74                           31
# 762                        62                            0
# 763                        76                           48
# 764                        70                           27
# 765                        72                           23
# 766                        60                            0
# 767                        70                           31
#
#      2-Hour serum insulin  Body mass index  Diabetes pedigree function  Age
# 0                       0             33.6                       0.627   50
# 1                       0             26.6                       0.351   31
# 2                       0             23.3                       0.672   32
# 3                      94             28.1                       0.167   21
# 4                     168             43.1                       2.288   33
# 5                       0             25.6                       0.201   30
# 6                      88             31.0                       0.248   26
# 7                       0             35.3                       0.134   29
# 8                     543             30.5                       0.158   53
# 9                       0              0.0                       0.232   54
# 10                      0             37.6                       0.191   30
# 11                      0             38.0                       0.537   34
# 12                      0             27.1                       1.441   57
# 13                    846             30.1                       0.398   59
# 14                    175             25.8                       0.587   51
# 15                      0             30.0                       0.484   32
# 16                    230             45.8                       0.551   31
# 17                      0             29.6                       0.254   31
# 18                     83             43.3                       0.183   33
# 19                     96             34.6                       0.529   32
# 20                    235             39.3                       0.704   27
# 21                      0             35.4                       0.388   50
# 22                      0             39.8                       0.451   41
# 23                      0             29.0                       0.263   29
# 24                    146             36.6                       0.254   51
# 25                    115             31.1                       0.205   41
# 26                      0             39.4                       0.257   43
# 27                    140             23.2                       0.487   22
# 28                    110             22.2                       0.245   57
# 29                      0             34.1                       0.337   38
# ..                    ...              ...                         ...  ...
# 738                   160             36.6                       0.453   21
# 739                     0             39.5                       0.293   42
# 740                   150             42.3                       0.785   48
# 741                    94             30.8                       0.400   26
# 742                   116             28.5                       0.219   22
# 743                     0             32.7                       0.734   45
# 744                   140             40.6                       1.174   39
# 745                   105             30.0                       0.488   46
# 746                     0             49.3                       0.358   27
# 747                    57             46.3                       1.096   32
# 748                   200             36.4                       0.408   36
# 749                     0             24.3                       0.178   50
# 750                     0             31.2                       1.182   22
# 751                    74             39.0                       0.261   28
# 752                     0             26.0                       0.223   25
# 753                   510             43.3                       0.222   26
# 754                     0             32.4                       0.443   45
# 755                   110             36.5                       1.057   37
# 756                     0             32.0                       0.391   39
# 757                     0             36.3                       0.258   52
# 758                     0             37.5                       0.197   26
# 759                     0             35.5                       0.278   66
# 760                    16             28.4                       0.766   22
# 761                     0             44.0                       0.403   43
# 762                     0             22.5                       0.142   33
# 763                   180             32.9                       0.171   63
# 764                     0             36.8                       0.340   27
# 765                   112             26.2                       0.245   30
# 766                     0             30.1                       0.349   47
# 767                     0             30.4                       0.315   23
#
# [768 rows x 8 columns]

# %%
df['Body mass index'].plot.hist()

# %%
import collaborative_data_frame as cdf

df = cdf.CollaborativeDataFrame(df)
df
# Out:
# VBox(children=(HBox(children=(Button(description='Refresh', style=ButtonStyle()), Button(description='Commit',…

# %%
df.share()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-7-142925c5073a> in <module>
# ----> 1 df.share()
#
# ~/git/collaborativecleaning/notebook/collaborative_data_frame.py in share(self)
#     142     def share(self):
#     143         if not self.url:
# --> 144             id = self.db_client.db.datasets.insert({'data': self.to_csv()})
#     145             self.url = f"http://{self.hostname}/dataset/{id}"
#     146             self.monitor_changes()
#
# ~/anaconda3/envs/python36_new/lib/python3.6/site-packages/pymongo/collection.py in insert(self, doc_or_docs, manipulate, check_keys, continue_on_error, **kwargs)
#    3193             write_concern = WriteConcern(**kwargs)
#    3194         return self._insert(doc_or_docs, not continue_on_error,
# -> 3195                             check_keys, manipulate, write_concern)
#    3196
#    3197     def update(self, spec, document, upsert=False, manipulate=False,
#
# ~/anaconda3/envs/python36_new/lib/python3.6/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     612             return self._insert_one(
#     613                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 614                 bypass_doc_val, session)
#     615
#     616         ids = []
#
# ~/anaconda3/envs/python36_new/lib/python3.6/site-packages/pymongo/collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     600
#     601         self.__database.client._retryable_write(
# --> 602             acknowledged, _insert_command, session)
#     603
#     604         if not isinstance(doc, RawBSONDocument):
#
# ~/anaconda3/envs/python36_new/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1277     def _retryable_write(self, retryable, func, session):
#    1278         """Internal retryable write helper."""
# -> 1279         with self._tmp_session(session) as s:
#    1280             return self._retry_with_session(retryable, func, s, None)
#    1281
#
# ~/anaconda3/envs/python36_new/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python36_new/lib/python3.6/site-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1609             return
#    1610
# -> 1611         s = self._ensure_session(session)
#    1612         if s and close:
#    1613             with s:
#
# ~/anaconda3/envs/python36_new/lib/python3.6/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1596             # Don't make implicit sessions causally consistent. Applications
#    1597             # should always opt-in.
# -> 1598             return self.__start_session(True, causal_consistency=False)
#    1599         except (ConfigurationError, InvalidOperation):
#    1600             # Sessions not supported, or multiple users authenticated.
#
# ~/anaconda3/envs/python36_new/lib/python3.6/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1549
#    1550         # Raises ConfigurationError if sessions are not supported.
# -> 1551         server_session = self._get_server_session()
#    1552         opts = client_session.SessionOptions(**kwargs)
#    1553         return client_session.ClientSession(
#
# ~/anaconda3/envs/python36_new/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1582     def _get_server_session(self):
#    1583         """Internal: start or resume a _ServerSession."""
# -> 1584         return self._topology.get_server_session()
#    1585
#    1586     def _return_server_session(self, server_session, lock):
#
# ~/anaconda3/envs/python36_new/lib/python3.6/site-packages/pymongo/topology.py in get_server_session(self)
#     432                         readable_server_selector,
#     433                         self._settings.server_selection_timeout,
# --> 434                         None)
#     435
#     436             session_timeout = self._description.logical_session_timeout_minutes
#
# ~/anaconda3/envs/python36_new/lib/python3.6/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     198             if timeout == 0 or now > end_time:
#     199                 raise ServerSelectionTimeoutError(
# --> 200                     self._error_message(selector))
#     201
#     202             self._ensure_opened()
#
# ServerSelectionTimeoutError: 127.0.0.1:27017: [Errno 61] Connection refused

# %%
df['Body mass index'].plot.hist()

# %%
df.collaborators['Mashaal'].stack()

# %%
simple_policy = {
    'at_least': 1,
    'option': 'majority_vote'
}

df.resolve(simple_policy)
